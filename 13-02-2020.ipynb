# %%
# Import PyDrive and associated libraries.
# This only needs to be done once in a notebook.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once in a notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
# Out:
# Uploaded file with ID 1x9E4bln5xYtgsPIYnzGQbQCEZr46P5AQ

# %%
# Create & upload a text file.
uploaded = drive.CreateFile({'title': 'Sample file.txt'})
uploaded.SetContentString('Sample upload file content')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1ZFQJgmbo8cqLMZVavRd7o3ofsdOuYObA

# %%
# Search query reference:
# https://developers.google.com/drive/v2/web/search-parameters
listed = drive.ListFile({'q': "title contains '.txt' and 'root' in parents"}).GetList()
for file in listed:
  print('title {}, id {}'.format(file['title'], file['id']))
# Out:
# title Sample file.txt, id 1ZFQJgmbo8cqLMZVavRd7o3ofsdOuYObA
# title Sample file.txt, id 1x9E4bln5xYtgsPIYnzGQbQCEZr46P5AQ

# %%
# A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz
file_id = '1pcZD5Jbj6SdDGGmfNIp9JJFZseQimJc3' #https://drive.google.com/open?id=1pcZD5Jbj6SdDGGmfNIp9JJFZseQimJc3
downloaded = drive.CreateFile({'id': file_id})
print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# Out:
# Downloaded content "Daily Time Spent on Site,Age,Area Income,Daily Internet Usage,Ad Topic Line,City,Male,Country,Timestamp,Clicked on Ad
# 68.95,35,61833.9,256.09,Cloned 5thgeneration orchestration,Wrightburgh,0,Tunisia,2016-03-27 00:53:11,0
# 80.23,31,68441.85,193.77,Monitored national standardization,West Jodi,1,Nauru,2016-04-04 01:39:02,0
# 69.47,26,59785.94,236.5,Organic bottom-line service-desk,Davidton,0,San Marino,2016-03-13 20:35:42,0
# 74.15,29,54806.18,245.89,Triple-buffered reciprocal time-frame,West Terrifurt,1,Italy,2016-01-10 02:31:19,0
# 68.37,35,73889.99,225.58,Robust logistical utilization,South Manuel,0,Iceland,2016-06-03 03:36:18,0
# 59.99,23,59761.56,226.74,Sharable client-driven software,Jamieberg,1,Norway,2016-05-19 14:30:17,0
# 88.91,33,53852.85,208.36,Enhanced dedicated support,Brandonstad,0,Myanmar,2016-01-28 20:59:32,0
# 66.0,48,24593.33,131.76,Reactive local challenge,Port Jefferybury,1,Australia,2016-03-07 01:40:15,1
# ...

# %%
downloaded.GetContentFile('advertising.csv')

# %%
# !ls
# Out:
# adc.json  advertising.csv  sample_data

# %%
import pandas as pd

# %%
df = pd.read_csv('advertising.csv')

# %%
df.head()
# Out:
#    Daily Time Spent on Site  Age  ...            Timestamp  Clicked on Ad
# 0                     68.95   35  ...  2016-03-27 00:53:11              0
# 1                     80.23   31  ...  2016-04-04 01:39:02              0
# 2                     69.47   26  ...  2016-03-13 20:35:42              0
# 3                     74.15   29  ...  2016-01-10 02:31:19              0
# 4                     68.37   35  ...  2016-06-03 03:36:18              0
#
# [5 rows x 10 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.tail()
# Out:
#      Daily Time Spent on Site  Age  ...            Timestamp  Clicked on Ad
# 995                     72.97   30  ...  2016-02-11 21:49:00              1
# 996                     51.30   45  ...  2016-04-22 02:07:01              1
# 997                     51.63   51  ...  2016-02-01 17:24:57              1
# 998                     55.55   19  ...  2016-03-24 02:35:54              0
# 999                     45.01   26  ...  2016-06-03 21:43:21              1
#
# [5 rows x 10 columns]

# %%
dir(df)
# Out:
# ['Age',
#  'City',
#  'Country',
#  'Male',
#  'T',
#  'Timestamp',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
len(df)
# Out:
# 1000

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.loc[5]
# Out:
# Daily Time Spent on Site                              59.99
# Age                                                      23
# Area Income                                         59761.6
# Daily Internet Usage                                 226.74
# Ad Topic Line               Sharable client-driven software
# City                                              Jamieberg
# Male                                                      1
# Country                                              Norway
# Timestamp                               2016-05-19 14:30:17
# Clicked on Ad                                             0
# Name: 5, dtype: object

# %%
df_short = df[0 : 100]

# %%
df_short.shape
# Out:
# (100, 10)

# %%
df_short.head()
# Out:
#    Daily Time Spent on Site  Age  ...            Timestamp  Clicked on Ad
# 0                     68.95   35  ...  2016-03-27 00:53:11              0
# 1                     80.23   31  ...  2016-04-04 01:39:02              0
# 2                     69.47   26  ...  2016-03-13 20:35:42              0
# 3                     74.15   29  ...  2016-01-10 02:31:19              0
# 4                     68.37   35  ...  2016-06-03 03:36:18              0
#
# [5 rows x 10 columns]

# %%
df_shape = df[['Daily Time Spent on Site', 'Age', 'Area Income', 'Daily Internet Usage', 'Male']]

# %%
df_shape.shape
# Out:
# (1000, 5)

# %%
df_shape.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male
# 0                     68.95   35     61833.90                256.09     0
# 1                     80.23   31     68441.85                193.77     1
# 2                     69.47   26     59785.94                236.50     0
# 3                     74.15   29     54806.18                245.89     1
# 4                     68.37   35     73889.99                225.58     0

# %%
df_age = df_shape[df_shape['Age'] > 55]

# %%
df_age.head()
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male
# 32                      59.05   57     25583.29                169.23     1
# 34                      57.64   57     45580.92                133.81     1
# 110                     66.63   60     60333.38                176.98     0
# 149                     68.61   57     61770.34                150.29     0
# 182                     62.95   60     36752.24                157.04     0

# %%
df_age.shape
# Out:
# (19, 5)

# %%
df_age['Area Income'].describe()
# Out:
# count       19.000000
# mean     45468.317368
# std      11101.035448
# min      25583.290000
# 25%      39466.185000
# 50%      44248.520000
# 75%      54184.300000
# max      61770.340000
# Name: Area Income, dtype: float64

# %%
df_age.describe()
# Out:
#        Daily Time Spent on Site        Age  ...  Daily Internet Usage       Male
# count                 19.000000  19.000000  ...             19.000000  19.000000
# mean                  60.173684  58.157895  ...            162.590526   0.421053
# std                   10.474366   1.500487  ...             17.348505   0.507257
# min                   42.440000  56.000000  ...            133.810000   0.000000
# 25%                   53.885000  57.000000  ...            151.735000   0.000000
# 50%                   60.230000  58.000000  ...            157.040000   0.000000
# 75%                   66.710000  59.500000  ...            171.330000   1.000000
# max                   80.300000  61.000000  ...            198.300000   1.000000
#
# [8 rows x 5 columns]

# %%
g = df_age.groupby(['Male'])

# %%
for key , df_key in g:
  print(key)
  print(df_key)
# Out:
# 0
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male
# 110                     66.63   60     60333.38                176.98     0
# 149                     68.61   57     61770.34                150.29     0
# 182                     62.95   60     36752.24                157.04     0
# 208                     59.51   58     39132.64                140.83     0
# 248                     42.44   56     43450.11                168.27     0
# 358                     51.38   59     42362.49                158.56     0
# 508                     80.30   58     49090.51                173.43     0
# 552                     56.39   58     32252.38                154.23     0
# 709                     77.80   57     43708.88                152.94     0
# 748                     45.11   58     39799.73                195.69     0
# 923                     47.00   56     50491.45                149.53     0
# 1
# ...

# %%
df_age.groupby(['Male']).mean()
# Out:
#       Daily Time Spent on Site        Age   Area Income  Daily Internet Usage
# Male
# 0                    59.829091  57.909091  45376.740909            161.617273
# 1                    60.647500  58.500000  45594.235000            163.928750

# %%
df_age.groupby(['Male']).describe()
# Out:
#      Daily Time Spent on Site                        ... Daily Internet Usage
#                         count       mean        std  ...                  50%     75%     max
# Male                                                 ...
# 0                        11.0  59.829091  12.814221  ...              157.040  170.85  195.69
# 1                         8.0  60.647500   6.862710  ...              161.195  172.98  198.30
#
# [2 rows x 32 columns]

# %%
import matplotlib as plt

# %%
import seaborn as sns
sns.set()

# %%
sns.pairplot(df_age, diag_kind='hist')

# %%
sns.pairplot(df_age, diag_kind='hist', hue = 'Male')

# %% [markdown]
# Debugging in python

# %%
import numpy as np

# %%
def factorial(x):
  if x == 0:
    return 1
  else:
    return x * factorial(x - 1)

# %%
factorial(5)
# Out:
# 120

# %%
def code_to_debug(x):
  import pdb; pdb.set_trace()
  for i in range(10):
    x = np.random.random()
    factorial(x)

# %%
code_to_debug(5)
# Out:
# > <ipython-input-65-ce6908ada228>(3)code_to_debug()
# -> for i in range(10):
# (Pdb) n
# > <ipython-input-65-ce6908ada228>(4)code_to_debug()
# -> x = np.random.random()
# (Pdb) n
# > <ipython-input-65-ce6908ada228>(5)code_to_debug()
# -> factorial(x)
# (Pdb) help
#
# Documented commands (type help <topic>):
# ...
# EOF    c          d        h         list      q        rv       undisplay
# a      cl         debug    help      ll        quit     s        unt
# alias  clear      disable  ignore    longlist  r        source   until
# args   commands   display  interact  n         restart  step     up
# b      condition  down     j         next      return   tbreak   w
# break  cont       enable   jump      p         retval   u        whatis
# bt     continue   exit     l         pp        run      unalias  where
#
# Miscellaneous help topics:
# ...
# exec  pdb
#
# (Pdb) help step
# s(tep)
#         Execute the current line, stop at the first possible occasion
# ...

# %%
def factorial_debug(x):
  if not isinstance(x, int):
    print("This method only supports integers")
    return -1
  if x == 0:
    return 1
  else:
    return x * factorial_debug(x - 1)

# %%
def code_to_debug2():
  import pdb; pdb.set_trace()
  for i in range(10):
    x = np.random.random()
    factorial_debug(x)

# %%
code_to_debug2()
# Out:
# > <ipython-input-68-9608bbdaf7db>(3)code_to_debug2()
# -> for i in range(10):
# (Pdb) ?
#
# Documented commands (type help <topic>):
# ...
# EOF    c          d        h         list      q        rv       undisplay
# a      cl         debug    help      ll        quit     s        unt
# alias  clear      disable  ignore    longlist  r        source   until
# args   commands   display  interact  n         restart  step     up
# b      condition  down     j         next      return   tbreak   w
# break  cont       enable   jump      p         retval   u        whatis
# bt     continue   exit     l         pp        run      unalias  where
#
# Miscellaneous help topics:
# ...
# exec  pdb
#
# (Pdb) c
# This method only supports integers
# This method only supports integers
# This method only supports integers
# This method only supports integers
# This method only supports integers
# This method only supports integers
# This method only supports integers
# This method only supports integers
# ...

# %%
code_to_debug2()
# Out:
# > <ipython-input-68-9608bbdaf7db>(3)code_to_debug2()
# -> for i in range(10):
# (Pdb) ?
#
# Documented commands (type help <topic>):
# ...
# EOF    c          d        h         list      q        rv       undisplay
# a      cl         debug    help      ll        quit     s        unt
# alias  clear      disable  ignore    longlist  r        source   until
# args   commands   display  interact  n         restart  step     up
# b      condition  down     j         next      return   tbreak   w
# break  cont       enable   jump      p         retval   u        whatis
# bt     continue   exit     l         pp        run      unalias  where
#
# Miscellaneous help topics:
# ...
# exec  pdb
#
# (Pdb) 4
# 4
# (Pdb) 6
# 6
# (Pdb) v
# *** NameError: name 'v' is not defined
# (Pdb) c
# This method only supports integers
# This method only supports integers
# This method only supports integers
# This method only supports integers
# This method only supports integers
# This method only supports integers
# ...
